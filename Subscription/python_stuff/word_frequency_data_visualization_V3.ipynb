# %%
from __future__ import print_function, division

from textblob import TextBlob

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import operator
import string

sns.set()


#Import data from the file into a SERIES OF LISTS?
raw_data = pd.read_csv("Update_Case_Data_V2.csv")

clean_data=raw_data.copy()

clean_data['word_count']=clean_data['SUBJ_TEXT'].apply(lambda x: len(str(x).split(" ")))

for index, row in clean_data.iterrows():
    if pd.isnull(row['SUBJ_TEXT']) or pd.isnull(row['LABEL']) or row['LABEL']!='PAYMENT ISSUE' or row['word_count']<10:
        clean_data.drop(index,inplace=True)



#review_data[['Review Text','word_count']].head()

clean_data['n_grams']=clean_data['SUBJ_TEXT'].apply(lambda x: TextBlob(x).ngrams(4))

words=[]

word_freq={}

for word in clean_data['SUBJ_TEXT']:
    words.extend(word.split(" "))

#Clean the text
things_to_remove=string.punctuation
table = str.maketrans('', '', things_to_remove)
cleaned_words = [w.translate(table) for w in words]
cleaned_words = [word.lower() for word in cleaned_words]

#Determine how often certain n_grams appear
n_grams=[]
n_gram_freq={}

for ngrams in clean_data['n_grams']:
    for gram in ngrams:
        n_grams.append(str(gram))
        if gram in n_grams:
            n_gram_freq[str(gram)]+=1;
        else:
            n_gram_freq[str(gram)]=1;

complex_words=[]
for word in cleaned_words[:]:
    if(len(word)>4 and word!=''):
        complex_words.append(word)
        if word in word_freq:
            word_freq[word]+=1;
        else:
            word_freq[word]=1;


word_freq_cleaned={}

for key in word_freq:
    for word in complex_words:
        if key == word and word_freq[key]>10:
            word_freq_cleaned.update({key:word_freq[key]})

#create list of all cleaned words
list_of_keys=[]

for key in word_freq_cleaned:
    list_of_keys.append(key)

#create list of all frequency
list_of_freq=[]
for key in word_freq_cleaned:
    list_of_freq.append(word_freq[key])

#print(list_of_freq)


df=pd.DataFrame(list_of_freq,index=list_of_keys,columns=['Word Frequency for Payment Issues'])
df=df.sort_values(by='Word Frequency for Payment Issues')
#print(df)

blob1=TextBlob(raw_data['SUBJ_TEXT'][2]).ngrams(1)
blob2=TextBlob(raw_data['SUBJ_TEXT'][1]).ngrams(1)

clean_data
# Out:
#                  ENTL_ID         SBSCR_NM             CASE_ID  \
# 56    55038000004JTTeAAO    AMS-100018447  5003800000wvlgLAAQ
# 61    55038000004Ju1fAAC  AMS-SP1270261-1  5003800000xXIvrAAG
# 65    55038000004Jw2ZAAS     AP-200003038  5003800000wyDuOAAU
# 71    55038000004JXEEAA4  AMS-CR1247420-1  5003800000wYEwsAAG
# 81    55038000004K1j9AAC    AMS-100019448  5003800000wvdsbAAA
# 95    55038000004KGuCAAW  AMS-CR1293561-1  5003800000wwvD9AAI
# 100   55038000004tnA1AAI    AMS-100005777  5003800000u5EQkAAM
# 118   55038000005Ba1JAAS    EM-SP273597-1  5003800000vNYTZAA4
# 128   55038000005Ba84AAC   EM-CR1252546-1  5003800000uyeNTAAY
# 135   55038000005BaCEAA0   EM-CR1256383-1  5003800000xPV36AAG
# 139   55038000005BacOAAS    EM-SP277692-1  5003800000te44QAAQ
# 150   55038000005BafPAAS   EM-CR1259629-1  5003800000vNfTWAA0
# 153   55038000005BagHAAS   EM-SP1284924-1  5003800000vsNTXAA2
# 158   55038000005BaHqAAK    EM-SP276274-1  5003800000vO1xGAAS
# 177   55038000005BaLXAA0   EM-CR1280698-1  5003800000wYea0AAC
# 178   55038000005BaMiAAK    EM-SP275251-1  5003800000u5ebFAAQ
# 186   55038000005BaPsAAK    EM-SP276824-1  5003800000wYq3PAAS
# 195   55038000005BaU4AAK   EM-CR1258734-1  5003800000vNYRsAAO
# 200   55038000005BaVRAA0   EM-CR1262044-1  5003800000vN61VAAS
# 229   55038000005Bdn3AAC    JP-SP275498-1  5003800000vl2JwAAI
# 231   55038000005BdomAAC    AP-SP239161-1  5003800000vO2b6AAC
# 250   55038000005BeBoAAK    EM-SP239189-1  5003800000vO5z1AAC
# 251   55038000005BeBSAA0    EM-SP238977-1  5003800000vO85zAAC
# 254   55038000005BeCfAAK    EM-SP242365-1  5003800000vlPYKAA2
# 265   55038000005BeLbAAK   EM-CR1263285-1  5003800000wZlwQAAS
# 275   55038000005BeSGAA0    EM-SP267538-1  5003800000xS1h6AAC
# 283   55038000005BetZAAS    EM-SP240350-1  5003800000wZdccAAC
# 324   55038000005BqOIAA0    AMS-100006378  5003800000wZPCaAAO
# 338   55038000005BYtmAAG   JP-CR1310311-1  5003800000y6JNsAAM
# 341   55038000005BYu7AAG    EM-SP243012-1  5003800000viP9iAAE
# ...                  ...              ...                 ...
# 874   55038000006G3QfAAK  AMS-SP1258237-1  5003800000vN7MeAAK
# 884   55038000006GESaAAO     AP-200001707  5003800000uae0QAAQ
# 925   55038000006GXO0AAO   AMS-SP276603-1  5003800000v00cKAAQ
# 946   55038000006HHj1AAG  AMS-CR1262739-1  5003800000vN2YDAA0
# 952   55038000006HMIvAAO    AMS-100011533  5003800000w3LmjAAE
# 957   55038000006HPDpAAO  AMS-CR1263971-1  5003800000v17gUAAQ
# 964   55038000006Hv2RAAS     EM-400006943  5003800000w4e70AAA
# 967   55038000006HztvAAC  AMS-SP1247616-1  5003800000v1B90AAE
# 970   55038000006I6mJAAS  AMS-SP1265993-1  5003800000xXwUOAA0
# 971   55038000006I6nCAAS  AMS-CR1265911-1  5003800000vNFfxAAG
# 991   55038000006J7iUAAS  AMS-SP1270705-1  5003800000vQdhNAAS
# 992   55038000006J7OCAA0    AMS-100013521  5003800000vQM1XAAW
# 995   55038000006JCpXAAW  AMS-CR1271497-1  5003800000viWKTAA2
# 1004  55038000006JgfNAAS  AMS-CR1269354-1  5003800000vjlt6AAA
# 1005  55038000006JGPcAAO    AMS-100013831  5003800000vQmseAAC
# 1011  55038000006Jj0UAAS  AMS-SP1271233-1  5003800000vjJuhAAE
# 1012  55038000006JJRKAA4   AMS-SP274293-1  5003800000wXdMpAAK
# 1020  55038000006JmzSAAS    AMS-100014644  5003800000w3cweAAA
# 1025  55038000006JqzwAAC    AMS-100014728  5003800000vldGVAAY
# 1098  55038000006L5lmAAC  AMS-CR1281235-1  5003800000wS8YfAAK
# 1099  55038000006L5loAAC  AMS-SP1278660-1  5003800000vtRBrAAM
# 1105  55038000006L97PAAS  AMS-SP1133912-1  5003800000w5sbJAAQ
# 1131  55038000006QlGvAAK  AMS-CR1247005-1  5003800000vu1vqAAA
# 1133  55038000006QmMUAA0   AMS-SP281079-1  5003800000wZ4kdAAC
# 1138  55038000006QqePAAS  AMS-SP1136595-1  5003800000wZpSvAAK
# 1167  55038000006S0aoAAC  AMS-SP1287219-1  5003800000xQrwrAAC
# 1175  55038000006S4msAAC  AMS-CR1281341-1  5003800000wTpuOAAS
# 1177  55038000006WA0mAAG  AMS-CR1294477-1  5003800000wx3BfAAI
# 1195  55038000006YZpqAAG    AMS-100020197  5003800000xS6zUAAS
# 1202  55038000006Zd3CAAS     AP-200003422  5003800000xXsYRAA0
#
#                  ACCT_ID                                    SUBJ_TEXT_DIRTY  \
# 56    0013800001JuZefAAF  I have been billed and charged incorrectly for...
# 61    0013800001BQTPsAAP  No longer employed by this company and was usi...
# 65    0013800001IWK5YAAX  Need some more explanation on why you charged ...
# 71    0015000000sTrjLAAS  I need my billing address updated to PO Box 25...
# 81    0015000000xaBDAAA2  I want to cancel my order and receive a refund...
# 95    00138000019rFYUAA2  I am trying to update the billing information ...
# 100   0015000000sWqzoAAC  I cannot purchase additional licenses: I get a...
# 118   00150000015Oz80AAC  My CB has expired and I would like to update c...
# 128   0015000000uZVPXAA4  How to change payment details for our hosted e...
# 135   00138000015RbjWAAS  I cannot update my credit card details as it s...
# 139   00138000015uifbAAA  I am not able to add new card details and my c...
# 150   00138000015SHaYAAW  I need to update my card details so that I can...
# 153   0015000000xbXktAAE  Need to change address so i can update my cred...
# 158   0015000000xYORVAA4  Received email that payment was declined. I do...
# 177   00138000018wZNLAA2  cant update expired credit card details on Sub...
# 178   0013800001BTUDwAAP  How can we change the number of user accounts ...
# 186   0015000000qoNtnAAE  I need to update my billing address to match t...
# 195   0015000000ir8UYAAY  Bekomme immer wieder Mails mit  Your payment w...
# 200   0015000000xYazpAAC  Trying to update card details but get these me...
# 229   0015000000uaNRrAAM  I would like to change my credit card informat...
# 231   0015000000xYcLZAA0  Our renewal has declined as credit card detail...
# 250   0015000000xYdMWAA0  Problems with the VISA card, it was changed in...
# 251   0015000000xYaqaAAC  I'm being asked to update my payment details, ...
# 254   0015000000xbDThAAM  The credit card details are claimed to be wron...
# 265   0015000000xYa7cAAC  You have charged my creditcard at the 28.02 wi...
# 275   0013800001AQqGpAAL  Symantec Support ID number: SP267538-1. I have...
# 283   0015000000xYrNsAAK  On Manage Subscription Renewal page, I want ch...
# 324   0015000000Swk7OAAR  I have a problem buying your product. The page...
# 338   0013800001BT29AAAT  My credit card information & billing address h...
# 341   0015000000xbXR8AAM  I decided to renew my SEP SBE product for a fu...
# ...                  ...                                                ...
# 874   0015000000oxjv9AAA  We received an email this morning stating that...
# 884   0013800001KnLnOAAV  A purchase was made today of Symantec Endpoint...
# 925   001380000185jWAAAY  Please I need Refunds for auto-renewal subscri...
# 946   001380000166qsMAAQ   I keep getting notices that my payment method...
# 952   0015000000fYc7GAAS  Hello, need details of what exactly I was char...
# 957   0015000000is0cwAAA  Need to update credit card information since y...
# 964   0013800001LyJMLAA3  I have bought the wrong product for my setup. ...
# 967   0013800001CuAa8AAF  Where can I see a summary of my past bills? Wh...
# 970   0015000000p0QJqAAM  Issue with being notified of an expiring subsc...
# 971   0015000000xY4CiAAK  We would like to stop using your service and r...
# 991   0015000000p0MAJAA2  I have cancelled my services but just received...
# 992   0013800001LzPjqAAF  I would like to submit my company's tax exempt...
# 995   0015000000xaYPgAAM  How do I remove my credit card information fro...
# 1004  0015000000xZBESAA4  The website to update my expired credit card i...
# 1005  0013800001LzcPNAAZ  The payment of our licenses have been declined...
# 1011  0013800001854FWAAY  How do I download or receive an invoice for th...
# 1012  00138000015R9CgAAK  yesterday I had an automatic renew, howeverr i...
# 1020  0015000000xbMNWAA2  I bought a new subscription but it did not app...
# 1025  0013800001M0a3wAAB  We purchased Endpoint Protection by mistake an...
# 1098  001500000108KGcAAM  Billing address is empty, how do I change it? ...
# 1099  00150000015PyhcAAC  Hi, it looks like we have 2 accounts with Syma...
# 1105  001500000108L74AAE  RECEIVED THIS E-MAIL As part of Enterprise Sub...
# 1131  0015000000lItU0AAK  How do I update my billing address in order to...
# 1133  0013800001GpidPAAR  I require an invoice and proof of payment for ...
# 1138  001500000109HXIAA2  I renwed my subscription, but now I am being c...
# 1167  0013800001852B8AAI  Remove  Billing Address  and on-file credit ca...
# 1175  0015000000iuKXuAAM  Symantec Support ID number: CR1281341-1.   I r...
# 1177  0013800001AMnYMAA1  You were supposed to cancel auto renewal with ...
# 1195  0013800001L7xnuAAB  How do i change my billing address? Credit car...
# 1202  0013800001KoDC0AAN  I have been charged multiple times for an annu...
#
#                                               SUBJ_TEXT          LABEL  \
# 56    I have been billed and charged incorrectly for...  PAYMENT ISSUE
# 61    No longer employed by this company and was usi...  PAYMENT ISSUE
# 65    Need some more explanation on why you charged ...  PAYMENT ISSUE
# 71    I need my billing address updated to PO Box 25...  PAYMENT ISSUE
# 81    I want to cancel my order and receive a refund...  PAYMENT ISSUE
# 95    I am trying to update the billing information ...  PAYMENT ISSUE
# 100   I cannot purchase additional licenses: I get a...  PAYMENT ISSUE
# 118   My CB has expired and I would like to update c...  PAYMENT ISSUE
# 128   How to change payment details for our hosted e...  PAYMENT ISSUE
# 135   I cannot update my credit card details as it s...  PAYMENT ISSUE
# 139   I am not able to add new card details and my c...  PAYMENT ISSUE
# 150   I need to update my card details so that I can...  PAYMENT ISSUE
# 153   Need to change address so i can update my cred...  PAYMENT ISSUE
# 158   Received email that payment was declined. I do...  PAYMENT ISSUE
# 177   cant update expired credit card details on Sub...  PAYMENT ISSUE
# 178   How can we change the number of user accounts ...  PAYMENT ISSUE
# 186   I need to update my billing address to match t...  PAYMENT ISSUE
# 195   Bekomme immer wieder Mails mit  Your payment w...  PAYMENT ISSUE
# 200   Trying to update card details but get these me...  PAYMENT ISSUE
# 229   I would like to change my credit card informat...  PAYMENT ISSUE
# 231   Our renewal has declined as credit card detail...  PAYMENT ISSUE
# 250   Problems with the VISA card, it was changed in...  PAYMENT ISSUE
# 251   I'm being asked to update my payment details, ...  PAYMENT ISSUE
# 254   The credit card details are claimed to be wron...  PAYMENT ISSUE
# 265   You have charged my creditcard at the 28.02 wi...  PAYMENT ISSUE
# 275   Symantec Support ID number: SP267538-1. I have...  PAYMENT ISSUE
# 283   On Manage Subscription Renewal page, I want ch...  PAYMENT ISSUE
# 324   I have a problem buying your product. The page...  PAYMENT ISSUE
# 338   My credit card information & billing address h...  PAYMENT ISSUE
# 341   I decided to renew my SEP SBE product for a fu...  PAYMENT ISSUE
# ...                                                 ...            ...
# 874   We received an email this morning stating that...  PAYMENT ISSUE
# 884   A purchase was made today of Symantec Endpoint...  PAYMENT ISSUE
# 925   Please I need Refunds for auto-renewal subscri...  PAYMENT ISSUE
# 946    I keep getting notices that my payment method...  PAYMENT ISSUE
# 952   Hello, need details of what exactly I was char...  PAYMENT ISSUE
# 957   Need to update credit card information since y...  PAYMENT ISSUE
# 964   I have bought the wrong product for my setup. ...  PAYMENT ISSUE
# 967   Where can I see a summary of my past bills? Wh...  PAYMENT ISSUE
# 970   Issue with being notified of an expiring subsc...  PAYMENT ISSUE
# 971   We would like to stop using your service and r...  PAYMENT ISSUE
# 991   I have cancelled my services but just received...  PAYMENT ISSUE
# 992   I would like to submit my company's tax exempt...  PAYMENT ISSUE
# 995   How do I remove my credit card information fro...  PAYMENT ISSUE
# 1004  The website to update my expired credit card i...  PAYMENT ISSUE
# 1005  The payment of our licenses have been declined...  PAYMENT ISSUE
# 1011  How do I download or receive an invoice for th...  PAYMENT ISSUE
# 1012  yesterday I had an automatic renew, howeverr i...  PAYMENT ISSUE
# 1020  I bought a new subscription but it did not app...  PAYMENT ISSUE
# 1025  We purchased Endpoint Protection by mistake an...  PAYMENT ISSUE
# 1098  Billing address is empty, how do I change it? ...  PAYMENT ISSUE
# 1099  Hi, it looks like we have 2 accounts with Syma...  PAYMENT ISSUE
# 1105  RECEIVED THIS E-MAIL As part of Enterprise Sub...  PAYMENT ISSUE
# 1131  How do I update my billing address in order to...  PAYMENT ISSUE
# 1133  I require an invoice and proof of payment for ...  PAYMENT ISSUE
# 1138  I renwed my subscription, but now I am being c...  PAYMENT ISSUE
# 1167  Remove  Billing Address  and on-file credit ca...  PAYMENT ISSUE
# 1175  Symantec Support ID number: CR1281341-1.   I r...  PAYMENT ISSUE
# 1177  You were supposed to cancel auto renewal with ...  PAYMENT ISSUE
# 1195  How do i change my billing address? Credit car...  PAYMENT ISSUE
# 1202  I have been charged multiple times for an annu...  PAYMENT ISSUE
#
#       word_count                                            n_grams
# 56            13  [[I, have, been, billed], [have, been, billed,...
# 61            15  [[No, longer, employed, by], [longer, employed...
# 65            10  [[Need, some, more, explanation], [some, more,...
# 71            24  [[I, need, my, billing], [need, my, billing, a...
# 81            45  [[I, want, to, cancel], [want, to, cancel, my]...
# 95            42  [[I, am, trying, to], [am, trying, to, update]...
# 100           46  [[I, can, not, purchase], [can, not, purchase,...
# 118           21  [[My, CB, has, expired], [CB, has, expired, an...
# 128           10  [[How, to, change, payment], [to, change, paym...
# 135           32  [[I, can, not, update], [can, not, update, my]...
# 139           15  [[I, am, not, able], [am, not, able, to], [not...
# 150           29  [[I, need, to, update], [need, to, update, my]...
# 153           12  [[Need, to, change, address], [to, change, add...
# 158           27  [[Received, email, that, payment], [email, tha...
# 177           11  [[cant, update, expired, credit], [update, exp...
# 178           40  [[How, can, we, change], [can, we, change, the...
# 186           12  [[I, need, to, update], [need, to, update, my]...
# 195           11  [[Bekomme, immer, wieder, Mails], [immer, wied...
# 200           38  [[Trying, to, update, card], [to, update, card...
# 229           13  [[I, would, like, to], [would, like, to, chang...
# 231           16  [[Our, renewal, has, declined], [renewal, has,...
# 250           25  [[Problems, with, the, VISA], [with, the, VISA...
# 251           16  [[I, 'm, being, asked], ['m, being, asked, to]...
# 254           30  [[The, credit, card, details], [credit, card, ...
# 265           24  [[You, have, charged, my], [have, charged, my,...
# 275           33  [[Symantec, Support, ID, number], [Support, ID...
# 283           32  [[On, Manage, Subscription, Renewal], [Manage,...
# 324           15  [[I, have, a, problem], [have, a, problem, buy...
# 338           30  [[My, credit, card, information], [credit, car...
# 341           51  [[I, decided, to, renew], [decided, to, renew,...
# ...          ...                                                ...
# 874           41  [[We, received, an, email], [received, an, ema...
# 884           19  [[A, purchase, was, made], [purchase, was, mad...
# 925           13  [[Please, I, need, Refunds], [I, need, Refunds...
# 946           21  [[I, keep, getting, notices], [keep, getting, ...
# 952           10  [[Hello, need, details, of], [need, details, o...
# 957           11  [[Need, to, update, credit], [to, update, cred...
# 964           40  [[I, have, bought, the], [have, bought, the, w...
# 967           20  [[Where, can, I, see], [can, I, see, a], [I, s...
# 970           27  [[Issue, with, being, notified], [with, being,...
# 971           25  [[We, would, like, to], [would, like, to, stop...
# 991           15  [[I, have, cancelled, my], [have, cancelled, m...
# 992           27  [[I, would, like, to], [would, like, to, submi...
# 995           12  [[How, do, I, remove], [do, I, remove, my], [I...
# 1004          11  [[The, website, to, update], [website, to, upd...
# 1005          48  [[The, payment, of, our], [payment, of, our, l...
# 1011          17  [[How, do, I, download], [do, I, download, or]...
# 1012          12  [[yesterday, I, had, an], [I, had, an, automat...
# 1020          26  [[I, bought, a, new], [bought, a, new, subscri...
# 1025          33  [[We, purchased, Endpoint, Protection], [purch...
# 1098          16  [[Billing, address, is, empty], [address, is, ...
# 1099          49  [[Hi, it, looks, like], [it, looks, like, we],...
# 1105          31  [[RECEIVED, THIS, E-MAIL, As], [THIS, E-MAIL, ...
# 1131          11  [[How, do, I, update], [do, I, update, my], [I...
# 1133          13  [[I, require, an, invoice], [require, an, invo...
# 1138          19  [[I, renwed, my, subscription], [renwed, my, s...
# 1167          11  [[Remove, Billing, Address, and], [Billing, Ad...
# 1175          37  [[Symantec, Support, ID, number], [Support, ID...
# 1177          13  [[You, were, supposed, to], [were, supposed, t...
# 1195          17  [[How, do, i, change], [do, i, change, my], [i...
# 1202          21  [[I, have, been, charged], [have, been, charge...
#
# [94 rows x 9 columns]
